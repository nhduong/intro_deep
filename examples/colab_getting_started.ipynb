# %% [markdown]
# # Experiencing a free of charge way to train deep models with high-performance GPU!
# - Nguyen Hai Duong
# - 2019/02/03

# %%
# In general, the hardware spec is given as follows:
# - GPU: 1x Tesla K80 , compute 3.7, having 2496 CUDA cores , 12GB GDDR5 VRAM
# - CPU: 2x Intel Xeon Processors @2.3Ghz i.e (1 core, 2 threads)
# - RAM: ~12.6 GB Available
# - Disk: ~33 GB Available

# %%
# Python version and hardware acceleration can be chosen via [Runtime] > [Change runtime type]
# <!> Python 3 and GPU options are recommended

# %%
# Google Colab can execute Linux commands starting with !
# For instance, let's check Linux version used by Google Colab by uname -a command
# !uname -a
# Out:
# Linux 5c1e8d482525 4.14.79+ #1 SMP Wed Dec 19 21:19:13 PST 2018 x86_64 x86_64 x86_64 GNU/Linux

# %%
# To install a Python package which is unavailable by default, use !pip install <name of package>
# In this example, we will install PyTorch and TorchVision packages
# !pip install torch torchvision
# Out:
# ...
#     100% |████████████████████████████████| 2.0MB 1.8MB/s
# ...
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# ...

# %%
# In practice, we need to store and process data from external hard drives. For the most part, Google Colab provides roughly 33 GB.
# However, after ~12 hours of execution, all stored data in Google Colab will be reset, that is, we will loose everything.
# Fortunately, all we need to do to address this issue is owning a Google account and a free space on Google Drive
# First things first, connect your Google Drive from Googe Colab by following the instruction
from google.colab import drive
drive.mount('/content/drive')

# %%
# Now you can access your Google Drive from Google Colab
# To double-check it, click [View] > [Table of contents] > go to [Files] tab > click [REFRESH]
# Your Google Drive should be mounted in "drive/My Drive"
# Let's inspect your Google Drive data structure
# !apt-get install tree
# !tree 'drive/My Drive' | tail -1
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (114 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 110856 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# 310 directories, 20893 files

# %%
# Let's read an image from my Google Drive and show it using Matplotlib and OpenCV
import matplotlib.pyplot as plt
import cv2
img = cv2.imread('drive/My Drive/CNU/gender_prediction/datasets/additional_testing_imgs/kim.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# In addition to the previous example, we can store our trained models (checkpoints) on Google Drive!
